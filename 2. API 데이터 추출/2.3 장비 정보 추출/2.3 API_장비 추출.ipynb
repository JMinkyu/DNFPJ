# %%
import json
import urllib.request
import urllib.parse
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
# 데이터 로드
urdata = pd.read_csv('2.2_Status_result.csv', encoding = 'euc-kr')

# 빈 데이터 프레임 생성
user_info = pd.DataFrame(columns = ['urname', 'weapon', 'jacket', 'shoulder', 'pants', 'shoes', 'waist', 'amulet', 'wrist', 'ring', 'support', 'magicstone', 'earring','fusion ring'])

for i in range(0, len(urdata)) :
    urname = urdata.iloc[i,0]
    svname = urdata.iloc[i,1]
    chid = urdata.iloc[i,3]
    requestData = requests.get(f'https://api.neople.co.kr/df/servers/{svname}/characters/{chid}/equip/equipment?apikey=M23RMaIB2JlKPyRWYRBKDb6UtE3NDTrS')
    jsonData = requestData.json()
    if requestData.status_code == 200 :
        api_result = pd.json_normalize(jsonData)
        user_equipment = pd.json_normalize(jsonData , record_path = 'equipment')
        try:
            weapon = user_equipment.loc[0, 'itemName']
            jacket = user_equipment.loc[2, 'itemName']
            shoulder = user_equipment.loc[3, 'itemName']
            pants = user_equipment.loc[4, 'itemName']
            shoes = user_equipment.loc[5, 'itemName']
            waist = user_equipment.loc[6, 'itemName']
            amulet = user_equipment.loc[7, 'itemName']
            wrist = user_equipment.loc[8, 'itemName']
            ring = user_equipment.loc[9, 'itemName']
            fusion_ring = user_equipment.loc[9, 'upgradeInfo.itemName']
            support = user_equipment.loc[10, 'itemName']
            magicstone = user_equipment.loc[11, 'itemName']
            earring = user_equipment.loc[12, 'itemName']

            user_equipment_name = pd.DataFrame({
                        'urname' : [urname],
                        'weapon' : [weapon],
                        'jacket' : [jacket],
                        'shoulder' : [shoulder],
                        'pants' : [pants],
                        'shoes' : [shoes],
                        'waist' : [waist],
                        'amulet' : [amulet],
                        'wrist' : [wrist],
                        'ring' : [ring],
                        'support' : [support],
                        'magicstone' : [magicstone],
                        'earring' : [earring],
                        'fusion ring' : [fusion_ring]
                        })
            user_info = pd.concat([user_info, user_equipment_name])
        except KeyError :
            user_equipment_name = pd.DataFrame({
                        'urname' : [urname],
                        'weapon' : None,
                        'jacket' : None,
                        'shoulder' : None,
                        'pants' : None,
                        'shoes' : None,
                        'waist' : None,
                        'amulet' : None,
                        'wrist' : None,
                        'ring' : None,
                        'support' : None,
                        'magicstone' : None,
                        'earring' : None,
                        'fusion ring' : None
                        })
            user_info = pd.concat([user_info, user_equipment_name])
    else :
        user_equipment_name = pd.DataFrame({
                        'urname' : [urname],
                        'weapon' : None,
                        'jacket' : None,
                        'shoulder' : None,
                        'pants' : None,
                        'shoes' : None,
                        'waist' : None,
                        'amulet' : None,
                        'wrist' : None,
                        'ring' : None,
                        'support' : None,
                        'magicstone' : None,
                        'earring' : None,
                        'fusion ring' : None
                        })
        user_info = pd.concat([user_info, user_equipment_name])
    print(f'{i}번째까지')

total_result_equipment = pd.merge(urdata, user_info, on = 'urname')
total_result_equipment.to_csv('2.3 result.csv', encoding='euc-kr')
# Out:
# 0번째까지
# 1번째까지
# 2번째까지
# 3번째까지
# 4번째까지
# 5번째까지
# 6번째까지
# 7번째까지
# 8번째까지
# 9번째까지
# 10번째까지
# 11번째까지
# 12번째까지
# 13번째까지
# 14번째까지
# 15번째까지
# 16번째까지
# 17번째까지
# 18번째까지
# 19번째까지
# 20번째까지
# 21번째까지
# 22번째까지
# 23번째까지
# 24번째까지
# 25번째까지
# 26번째까지
# 27번째까지
# 28번째까지
# 29번째까지
# 30번째까지
# 31번째까지
# 32번째까지
# 33번째까지
# 34번째까지
# 35번째까지
# 36번째까지
# 37번째까지
# 38번째까지
# 39번째까지
# 40번째까지
# 41번째까지
# 42번째까지
# 43번째까지
# 44번째까지
# 45번째까지
# 46번째까지
# 47번째까지
# 48번째까지
# 49번째까지
# 50번째까지
# 51번째까지
# 52번째까지
# 53번째까지
# 54번째까지
# 55번째까지
# 56번째까지
# 57번째까지
# 58번째까지
# 59번째까지
# 60번째까지
# 61번째까지
# 62번째까지
# 63번째까지
# 64번째까지
# 65번째까지
# 66번째까지
# 67번째까지
# 68번째까지
# 69번째까지
# 70번째까지
# 71번째까지
# 72번째까지
# 73번째까지
# 74번째까지
# 75번째까지
# 76번째까지
# 77번째까지
# 78번째까지
# 79번째까지
# 80번째까지
# 81번째까지
# 82번째까지
# 83번째까지
# 84번째까지
# 85번째까지
# 86번째까지
# 87번째까지

# %%
user_equipment_name = pd.DataFrame({
                    'urname' : [urname],
                    'weapon' : [weapon],
                    'jacket' : [jacket],
                    'shoulder' : [shoulder],
                    'pants' : [pants],
                    'shoes' : [shoes],
                    'waist' : [waist],
                    'amulet' : [amulet],
                    'wrist' : [wrist],
                    'ring' : [ring],
                    'support' : [support],
                    'magicstone' : [magicstone],
                    'earring' : [earring]})

# %%
user_equipment_name
# Out:
#   urname      weapon      jacket shoulder       pants   shoes   waist amulet  \
# 0    킴던던  근원을 삼킨 리볼버  리버시블 레더 코트   매니퓰레이션  로보티카 컴뱃 팬츠  엑셀러레이터  파워 플랜트   검은 별
#
#         wrist        ring support  magicstone     earring
# 0  억제된 마력의 팔찌  골렘의 중추석 반지  파괴된 생명  승리가 약속된 시간  폭풍을 삼킨 에너지
