# %%
import json
import urllib.request
import urllib.parse
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
urdata
# Out:
#         urname svname    rkpo                       characterId
# 0         ID결신  bakal  41,002  4663274c8e493bb43274ce15768a8cb9
# 1         연단된총   prey  41,001  45737067e047d0ee8dc255c53f150a68
# 2          킴던던   cain  41,001  4d0d7052aa62f8899489c9ad0011267c
# 3         구슬모양   cain  41,001  4d9cccd884cbb336d9c9f3fe48a13457
# 4       딜좀이놈들아   prey  41,001  3f979163c3355c45e6e8e4dd5040a52e
# ...        ...    ...     ...                               ...
# 216516    스핏라챠   cain  33,038  e477e2caa27c0e8b7071fcfad04e6f35
# 216517  Puming  bakal  33,038  f68ac5ee580b409322070dea0af32a87
# 216518    안보이천  anton  33,038  5e2a846591fc3f290779ea19f5b4bdd8
# 216519      도짬   prey  33,038  6d73c9f2cf20380da15a0bf316b56b2b
# 216520     8수라   prey  33,038  6367570a0d9324481d2fd06ff081c597
#
# [216520 rows x 4 columns]

# %%
# 데이터 로드
urdata = pd.read_csv('2.2_Status_result.csv', encoding = 'euc-kr')

# 빈 데이터 프레임 생성
user_info = pd.DataFrame(columns = ['urname', 'weapon', 'jacket', 'shoulder', 'pants', 'shoes', 'waist', 'amulet', 'wrist', 'ring', 'support', 'magicstone', 'earring','fusion ring'])

for i in range(0, 100) :
    urname = urdata.iloc[i,0]
    svname = urdata.iloc[i,1]
    chid = urdata.iloc[i,3]
    requestData = requests.get(f'https://api.neople.co.kr/df/servers/{svname}/characters/{chid}/equip/equipment?apikey=M23RMaIB2JlKPyRWYRBKDb6UtE3NDTrS')
    jsonData = requestData.json()
    if requestData.status_code == 200 :
        api_result = pd.json_normalize(jsonData)
        user_equipment = pd.json_normalize(jsonData , record_path = 'equipment')

        if user_equipment.loc[0, 'itemAvailableLevel'] == 105 :
            weapon = user_equipment.loc[0, 'itemName']
            jacket = user_equipment.loc[2, 'itemName']
            shoulder = user_equipment.loc[3, 'itemName']
            pants = user_equipment.loc[4, 'itemName']
            shoes = user_equipment.loc[5, 'itemName']
            waist = user_equipment.loc[6, 'itemName']
            amulet = user_equipment.loc[7, 'itemName']
            wrist = user_equipment.loc[8, 'itemName']
            ring = user_equipment.loc[9, 'itemName']
            fusion_ring = user_equipment.loc[9, 'upgradeInfo.itemName']
            support = user_equipment.loc[10, 'itemName']
            magicstone = user_equipment.loc[11, 'itemName']
            earring = user_equipment.loc[12, 'itemName']

            user_equipment_name = pd.DataFrame({
                            'urname' : [urname],
                            'weapon' : [weapon],
                            'jacket' : [jacket],
                            'shoulder' : [shoulder],
                            'pants' : [pants],
                            'shoes' : [shoes],
                            'waist' : [waist],
                            'amulet' : [amulet],
                            'wrist' : [wrist],
                            'ring' : [ring],
                            'support' : [support],
                            'magicstone' : [magicstone],
                            'earring' : [earring],
                            'fusion ring' : [fusion_ring]
                            })
            user_info = pd.concat([user_info, user_equipment_name])
        else :
            user_equipment_name = pd.DataFrame({
                            'urname' : [urname],
                            'weapon' : None,
                            'jacket' : None,
                            'shoulder' : None,
                            'pants' : None,
                            'shoes' : None,
                            'waist' : None,
                            'amulet' : None,
                            'wrist' : None,
                            'ring' : None,
                            'support' : None,
                            'magicstone' : None,
                            'earring' : None,
                            'fusion ring' : None
                            })
            user_info = pd.concat([user_info, user_equipment_name])
    else :
        user_equipment_name = pd.DataFrame({
                            'urname' : [urname],
                            'weapon' : None,
                            'jacket' : None,
                            'shoulder' : None,
                            'pants' : None,
                            'shoes' : None,
                            'waist' : None,
                            'amulet' : None,
                            'wrist' : None,
                            'ring' : None,
                            'support' : None,
                            'magicstone' : None,
                            'earring' : None,
                            'fusion ring' : None
                            })
        user_info = pd.concat([user_info, user_equipment_name])

total_result_equipment = pd.merge(urdata, user_info, on = 'urname')
total_result_equipment
# Out:
#     urname svname    rkpo                       characterId adventurename  \
# 0     ID결신  bakal  41,002  4663274c8e493bb43274ce15768a8cb9         축복의버프
# 1     연단된총   prey  41,001  45737067e047d0ee8dc255c53f150a68      심연부터광명까지
# 2      킴던던   cain  41,001  4d0d7052aa62f8899489c9ad0011267c          던던세상
# 3     구슬모양   cain  41,001  4d9cccd884cbb336d9c9f3fe48a13457       싸인해주는토끼
# 4   딜좀이놈들아   prey  41,001  3f979163c3355c45e6e8e4dd5040a52e      이게ㄹㅇ게임이냐
# ..     ...    ...     ...                               ...           ...
# 95  무자본소환사   prey  40,998  371ab5579cc20e321ab9da40b037b9c2          금숟가락
# 96   백어택피자   cain  40,997  8195f9bea53746defb52a329e4282260       맛있어서큰일난
# 97    부강의용   cain  40,997  ed44a7d077221b22fea080b8b1a13733        존윅과친구들
# 98  아질산나트륨   cain  40,997  f2b9297fe422989f12b7c8df8e365f03           아질산
# 99    재택교육  anton  40,997  fc7e564dc7ebb14fe04ee9832594e9a7        웨스트코스트
#
#     adventurelevel  resist  physical_defense  magical_defense  \
# 0             40.0    79.0              37.6             40.0
# 1             37.0    54.0              38.1             42.0
# 2             38.0    89.0              41.9             45.1
# 3             39.0    74.0              37.0             34.2
# 4             40.0    99.0              40.3             37.1
# ..             ...     ...               ...              ...
# 95            39.0   -21.0              30.1             36.8
# 96            40.0   103.0              37.4             39.8
# 97            40.0   171.0              32.7             30.3
# 98            40.0   149.0              48.3             46.7
# 99            37.0   161.0              32.4             38.8
#
#                 weapon  ...          pants        shoes       waist  \
# 0         결전의 로드 - 빙결사  ...      혼돈을 두른 장막       엑셀러레이터      파워 플랜트
# 1           근원을 삼킨 리볼버  ...      혼돈을 두른 장막       엑셀러레이터      파워 플랜트
# 2           근원을 삼킨 리볼버  ...     로보티카 컴뱃 팬츠       엑셀러레이터      파워 플랜트
# 3   결전의 십자가 - 크루세이더(여)  ...      언리밋 사이버네틱       내딛는 용기   쿨링 서포트 벨트
# 4   결전의 십자가 - 크루세이더(여)  ...  지치지 않는 여정의 하의       내딛는 용기   쿨링 서포트 벨트
# ..                 ...  ...            ...          ...         ...
# 95          근원을 삼킨 스태프  ...  깨지지 않는 빛바랜 신념       엑셀러레이터      파워 플랜트
# 96           근원을 삼킨 단검  ...      혼돈을 두른 장막       엑셀러레이터      파워 플랜트
# 97         결전의 도 - 아수라  ...     숨쉬는 자연의 생명  순환하는 자연의 섭리  순수한 자연의 이치
# 98           근원을 삼킨 소검  ...     로보티카 컴뱃 팬츠  사이버틱 스피드 부츠      파워 플랜트
# 99       결전의 봉 - 배틀메이지  ...     숨쉬는 자연의 생명  순환하는 자연의 섭리  순수한 자연의 이치
#
#        amulet         wrist          ring      support     magicstone  \
# 0        검은 별    억제된 마력의 팔찌    골렘의 중추석 반지       파괴된 생명     승리가 약속된 시간
# 1        검은 별    억제된 마력의 팔찌    골렘의 중추석 반지    딥 다이버 오리발     승리가 약속된 시간
# 2        검은 별    억제된 마력의 팔찌    골렘의 중추석 반지       파괴된 생명     승리가 약속된 시간
# 3      잠겨진 영역     흑화의 구속 팔찌     어댑터블 투톤 링     굴착 강화 파츠  생명이 깃든 초록빛 액체
# 4      잠겨진 영역  생명이 담긴 가죽 토시     어댑터블 투톤 링  드러나는 흐릿한 지식    자연에 녹아드는 이슬
# ..        ...           ...           ...          ...            ...
# 95       검은 별    억제된 마력의 팔찌    골렘의 중추석 반지    엔트 정령의 성배         잊혀진 기록
# 96       검은 별    억제된 마력의 팔찌    골렘의 중추석 반지   옵티컬 컴뱃 글래스     승리가 약속된 시간
# 97  올곧은 자의 이념    작은 풀잎의 순수함  뚜렷해지는 소멸된 사념     생명이 담긴 잔    자연에 녹아드는 이슬
# 98       검은 별    억제된 마력의 팔찌       이동하는 요새    엔트 정령의 성배      평화를 위한 투쟁
# 99  올곧은 자의 이념    작은 풀잎의 순수함  뚜렷해지는 소멸된 사념     굴착 강화 파츠         언비튼 메달
#
#             earring         fusion ring
# 0        폭풍을 삼킨 에너지     흑룡 : 끝없는 암흑의 굴레
# 1        폭풍을 삼킨 에너지     흑룡 : 끝없는 암흑의 굴레
# 2        폭풍을 삼킨 에너지                 NaN
# 3            시각의 관점      금룡 : 무한한 빛의 결계
# 4            시각의 관점      금룡 : 무한한 빛의 결계
# ..              ...                 ...
# 95           아득한 각인     흑룡 : 끝없는 암흑의 굴레
# 96       폭풍을 삼킨 에너지     흑룡 : 끝없는 암흑의 굴레
# 97       청명한 아침의 새싹      금룡 : 무한한 빛의 결계
# 98        아크로매틱 룸버스  천계 연합군 : 밝게 빛나는 희망
# 99  폭발형 : 소형 전술 플레어     흑룡 : 끝없는 암흑의 굴레
#
# [100 rows x 22 columns]

# %%
user_equipment
# Out:
#         slotId slotName                            itemId       itemName  \
# 0       WEAPON       무기  c1e43e8dee17e1666d25b39dcd0d41af  결전의 도 - 다크템플러
# 1        TITLE       칭호  f5c5e701d65823be81c19b10434ba460       한여름 밤의 꿈
# 2       JACKET       상의  3e18290e588b9d93576ec629d8d2a9ef      흙으로 빚은 자연
# 3     SHOULDER     머리어깨  b64213ec17d4a559227cd21717e01b14     피어나는 자연의 삶
# 4        PANTS       하의  2783870f2ae14db780268a1672f9e916     숨쉬는 자연의 생명
# 5        SHOES       신발  e88f45525a280cc2594051a55f930489    순환하는 자연의 섭리
# 6        WAIST       허리  8a2d1285ef05f7e703c764dbf605feda     순수한 자연의 이치
# 7       AMULET      목걸이  52b530f45e9c9696573feb607ffefe4f      올곧은 자의 이념
# 8        WRIST       팔찌  5ca915f03d8a5a625465366e58bdc67f      흑화의 구속 팔찌
# 9         RING       반지  509508d2bdb68a333a7e095ab6f86011   뚜렷해지는 소멸된 사념
# 10     SUPPORT     보조장비  bc4199484eedfd4282a2e31733fd8aef     옵티컬 컴뱃 글래스
# 11  MAGIC_STON      마법석  37522f61ef37c5b5251900c3345af96a    자연에 녹아드는 이슬
# 12     EARRING      귀걸이  fbd153de08e38753316ba906bcd0a180      아크로매틱 룸버스
#
#                           itemTypeId itemType  \
# 0   4ffb6f14b86f5c818a925bf58022686e       무기
# 1   e490f8cce6bacd43bef1e2f5e0c4943d     액세서리
# 2   b09752bfff1935188ea2735cd925a872      방어구
# 3   b09752bfff1935188ea2735cd925a872      방어구
# 4   b09752bfff1935188ea2735cd925a872      방어구
# 5   b09752bfff1935188ea2735cd925a872      방어구
# 6   b09752bfff1935188ea2735cd925a872      방어구
# 7   e490f8cce6bacd43bef1e2f5e0c4943d     액세서리
# 8   e490f8cce6bacd43bef1e2f5e0c4943d     액세서리
# 9   e490f8cce6bacd43bef1e2f5e0c4943d     액세서리
# 10  87ff665868ffd50f8aef7948548439bd     추가장비
# 11  87ff665868ffd50f8aef7948548439bd     추가장비
# 12  87ff665868ffd50f8aef7948548439bd     추가장비
#
#                     itemTypeDetailId itemTypeDetail  itemAvailableLevel  \
# 0   8d01a0691af67b319c70996f129f76b6              도                 105
# 1   691933a06ff114348a7db936fb0aec66             칭호                   1
# 2   fd2e4e03a93fb8096fca4d2187fb39db          판금 상의                 105
# 3   a4e1213018d003906149dffd2a2029e8        판금 머리어깨                 105
# 4   d944e7adc2b12b60036b0da689051147          판금 하의                 105
# 5   48e9f8b4f2ba996e22e2d9f176c9c8fd          판금 신발                 105
# 6   05e3f1f7234913d35c9fc209dde01a6d          판금 허리                 105
# 7   390e3966118b0c466ce9f8eae45e1629            목걸이                 105
# 8   80bddf423629c28c7b4459c328fdffaf             팔찌                 105
# 9   b04c7fb9b29b27b91a0a9e5a1822bc8f             반지                 105
# 10  2fef5d81b7f59f0c75241890a8d941c9           보조장비                 105
# 11  fe5f3db78175f5a3196385c688d29681            마법석                 105
# 12  601834074c49bb0e48cb65a75a8667bc            귀걸이                 105
#
#    itemRarity  ... growInfo.total.damage growInfo.total.buff  \
# 0          에픽  ...               13944.0              5268.0
# 1          레어  ...                   NaN                 NaN
# 2          에픽  ...               17190.0              5301.0
# 3          에픽  ...               17233.0              5314.0
# 4          에픽  ...               17190.0              5300.0
# 5          에픽  ...               17147.0              5287.0
# 6          에픽  ...               17147.0              5287.0
# 7          에픽  ...               11463.0              5295.0
# 8          에픽  ...                8548.0              5276.0
# 9          에픽  ...               17330.0              5288.0
# 10         에픽  ...               12063.0              5215.0
# 11         에픽  ...               14572.0              4964.0
# 12         에픽  ...               12133.0              5144.0
#
#     growInfo.total.level                                   growInfo.options  \
# 0                  276.0  [{'level': 69, 'expRate': 93.71, 'explain': '이...
# 1                    NaN                                                NaN
# 2                  284.0  [{'level': 71, 'expRate': 77.19, 'explain': '공...
# 3                  286.0  [{'level': 71, 'expRate': 86.95, 'explain': '공...
# 4                  284.0  [{'level': 70, 'expRate': 93.23, 'explain': '공...
# 5                  282.0  [{'level': 70, 'expRate': 63.73, 'explain': '공...
# 6                  282.0  [{'level': 70, 'expRate': 44.72, 'explain': '공...
# 7                  287.0  [{'level': 71, 'expRate': 22.22, 'explain': '장...
# 8                  290.0  [{'level': 73, 'expRate': 23.97, 'explain': '데...
# 9                  290.0  [{'level': 73, 'expRate': 24.3, 'explain': 'HP...
# 10                 283.0  [{'level': 71, 'expRate': 6.93, 'explain': '장착...
# 11                 276.0  [{'level': 69, 'expRate': 70.76, 'explain': '피...
# 12                 284.0  [{'level': 72, 'expRate': 72.25, 'explain': '각...
#
#                         machineRevolutionInfo.options  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'damage': 4685, 'buff': 1291, 'explain': '던전...
# 3   [{'damage': 5861, 'buff': 1291, 'explain': '던전...
# 4   [{'damage': 4685, 'buff': 1291, 'explain': '던전...
# 5                                                 NaN
# 6   [{'buff': 1291, 'explain': '공격 시 적을 20초 동안 출혈,...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#                   upgradeInfo.itemId upgradeInfo.itemName  enchant.explain  \
# 0                                NaN                  NaN              NaN
# 1                                NaN                  NaN              NaN
# 2   cef49e565beee41babb0d61fa6107176       뇌광 : 천둥을 품은 용심              NaN
# 3   424a5caa037bcf098cb50b70bc3b3117       뇌광 : 우레를 감싼 용익       스킬 공격력 +1%
# 4   ecb7bd892dce52ecb841231c6b3ebce3       뇌광 : 낙뢰를 내린 용각              NaN
# 5                                NaN                  NaN              NaN
# 6   d50ef0be2439cab87c0c2b83f1543fdd        포식 : 조여오는 올가미              NaN
# 7   568018f4d9ed013f352d412331ab67ba       진룡 : 잔혹한 용의 발톱              NaN
# 8   5285d14664a9aa41559ca68f440c3909       금룡 : 화려한 힘의 기원              NaN
# 9   6255f92b7b56a7ddd76f566a47ada800       진룡 : 무거운 철의 투지              NaN
# 10  56422d257499f7c60c7dad02d0f43db2  심연의 결집 : 정의되지 않는 존재              NaN
# 11  323e201088055e1ed622be84b7479103        슈페리어 : 매직 서클로              NaN
# 12                               NaN                  NaN              NaN
#
#                                    ispinsInfo.options  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   [{'buff': 1063, 'explain': '공격 시 충격파가 발생하며 적 무...
# 8   [{'buff': 1405, 'explain': '공격 시 30% 확률로 랜덤한 효...
# 9   [{'buff': 1405, 'explain': '공격 시 충격파 발생
# 충격파에 5...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#                         dimensionCloisterInfo.options
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  [{'damage': 2350, 'buff': 1178, 'explain': '스킬...
# 11  [{'damage': 8560, 'buff': 1291, 'explain': '공격...
# 12                                                NaN
#
# [13 rows x 27 columns]

# %%
user_equipment_name = pd.DataFrame({
                    'urname' : [urname],
                    'weapon' : [weapon],
                    'jacket' : [jacket],
                    'shoulder' : [shoulder],
                    'pants' : [pants],
                    'shoes' : [shoes],
                    'waist' : [waist],
                    'amulet' : [amulet],
                    'wrist' : [wrist],
                    'ring' : [ring],
                    'support' : [support],
                    'magicstone' : [magicstone],
                    'earring' : [earring]})

# %%
user_equipment_name
# Out:
#   urname      weapon      jacket shoulder       pants   shoes   waist amulet  \
# 0    킴던던  근원을 삼킨 리볼버  리버시블 레더 코트   매니퓰레이션  로보티카 컴뱃 팬츠  엑셀러레이터  파워 플랜트   검은 별
#
#         wrist        ring support  magicstone     earring
# 0  억제된 마력의 팔찌  골렘의 중추석 반지  파괴된 생명  승리가 약속된 시간  폭풍을 삼킨 에너지
